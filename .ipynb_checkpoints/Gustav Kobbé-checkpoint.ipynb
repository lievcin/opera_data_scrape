# %%
from bs4 import BeautifulSoup
import requests, re

# name = "Russia/Bolshoi.csv"
# csv = open(name, "w") 
# columnTitleRow = "opera_title\t opera_description\t date\t role\t artist\t url\n"
# csv.write(columnTitleRow)

url = "http://www.gutenberg.org/files/40540/40540-h/40540-h.htm"
r  = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

links_with_text = []
for a in soup.find_all('a', href=True): 
    if a.text: 
        links_with_text.append(a['href'])

# %%
pages_we_dont_want = ['Opera_Before_Gluck', 'Transcribers_Errata_List', 'Contents', 'Page_', 'Transcribers_Errata_List', 'INDEX', 'ILLUSTRATIONS', 'Schools_of_Opera', 'Why_Some_Operas_are_Rarely_Given']
def check_if_wanted(text):
    matched = True
    for page in pages_we_dont_want:
        if text in '#' + page:
            matched = False
            break
    return matched
links_with_text = [link for link in links_with_text if check_if_wanted(link) == True]
links_with_text = [link for link in links_with_text if link.isupper() == True]
links_with_text

# '#ORFEO_ED_EURIDICE'.isupper()

# check_if_wanted('#Transcribers_Errata_List')
# Out:
# ['#ORFEO_ED_EURIDICE',
#  '#ARMIDE',
#  '#IPHIGENIE_EN_TAURIDE',
#  '#LE_NOZZE_DI_FIGARO',
#  '#DON_GIOVANNI',
#  '#THE_MAGIC_FLUTE',
#  '#FIDELIO',
#  '#DER_FREISCHUTZ',
#  '#EURYANTHE',
#  '#OBERON',
#  '#RIENZI',
#  '#DUTCHMAN',
#  '#TANNHAUSER',
#  '#LOHENGRIN',
#  '#DIE_WALKURE',
#  '#SIEGFRIED',
#  '#GOTTERDAMMERUNG',
#  '#TRISTAN_UND_ISOLDE',
#  '#MEISTERSINGER',
#  '#PARSIFAL',
#  '#BARBIERE',
#  '#SEMIRAMIDE',
#  '#TELL',
#  '#SONNAMBULA',
#  '#NORMA',
#  '#PURITANI',
#  '#ELISIRE',
#  '#LUCREZIA',
#  '#LUCIA',
#  '#FIGLIA',
#  '#FAVORITA',
#  '#LINDA',
#  '#DON_PASQUALE',
#  '#ERNANI',
#  '#RIGOLETTO',
#  '#TROVATORE',
#  '#TRAVIATA',
#  '#BALLO',
#  '#BEFORE_AND_AFTER_UN_BALLO',
#  '#AIDA',
#  '#OTELLO',
#  '#FALSTAFF',
#  '#MEFISTOFELE',
#  '#MEFISTOFELE',
#  '#NERO',
#  '#GIOCONDA',
#  '#MEHUL',
#  '#MEHUL',
#  '#BOIELDIEU',
#  '#BOIELDIEU',
#  '#BOIELDIEU',
#  '#BOIELDIEU',
#  '#AUBER',
#  '#AUBER',
#  '#AUBER',
#  '#HEROLD',
#  '#HEROLD',
#  '#ADAM',
#  '#ADAM',
#  '#HALEVY',
#  '#HALEVY',
#  '#ROBERT_LE_DIABLE',
#  '#HUGUENOTS',
#  '#PROPHETE',
#  '#AFRICAINE',
#  '#ETOILE',
#  '#ETOILE',
#  '#BENVENUTO',
#  '#BEATRICE',
#  '#TROYENS',
#  '#DAMNATION',
#  '#MARTHA',
#  '#FAUST',
#  '#ROMEO',
#  '#MIGNON',
#  '#CARMEN',
#  '#PECHEURS',
#  '#DJAMILEH',
#  '#CAVALLERIA',
#  '#MASCHERE',
#  '#FRITZ',
#  '#IRIS',
#  '#LODOLETTA',
#  '#ISABEAU',
#  '#PAGLIACCI',
#  '#VILLI',
#  '#MANON_LESCAUT',
#  '#BOHEME',
#  '#TOSCA',
#  '#BUTTERFLY',
#  '#FANCIULLA',
#  '#RONDINE',
#  '#SUOR_ANGELICA',
#  '#TABARRO',
#  '#GIANNI_SCHICCHI',
#  '#FRANCESCA',
#  '#ORACOLO',
#  '#OTHER_LEONI',
#  '#OTHER_LEONI',
#  '#OTHER_LEONI',
#  '#TRE_RE',
#  '#OTHERS_MONTEMEZZI',
#  '#OTHERS_MONTEMEZZI',
#  '#GIOJELLI',
#  '#DONNE_CURIOSE',
#  '#SEGRETO',
#  '#DOCTOR_CUPID',
#  '#MADAME_SANS-GENE',
#  '#ANDRE_CHENIER',
#  '#FEDORA',
#  '#OTHERS_GIORDANO',
#  '#ERO',
#  '#ERO',
#  '#CONCHITA',
#  '#CONCHITA',
#  '#CRISTOFORO',
#  '#CRISTOFORO',
#  '#CRISPINO',
#  '#CRISPINO',
#  '#LORELEY',
#  '#LORELEY',
#  '#FEDORA',
#  '#GERMANIA',
#  '#GERMANIA',
#  '#HOFFMANN',
#  '#HOFFMANN',
#  '#LAKME',
#  '#LAKME',
#  '#SAMSON',
#  '#SAMSON',
#  '#ROI_DYS',
#  '#ROI_DYS',
#  '#GRISELIDIS',
#  '#GRISELIDIS',
#  '#THAIS',
#  '#MANON',
#  '#CID',
#  '#QUICHOTTE',
#  '#CENDRILLON',
#  '#NAVARRAISE',
#  '#JONGLEUR',
#  '#WERTHER',
#  '#HERODIADE',
#  '#SAPHO',
#  '#CLEOPATRE',
#  '#LOUISE',
#  '#LOUISE',
#  '#SALAMMBO',
#  '#SALAMMBO',
#  '#PELLEAS',
#  '#PELLEAS',
#  '#APHRODITE',
#  '#APHRODITE',
#  '#ATTAQUE',
#  '#ATTAQUE',
#  '#ARIANE',
#  '#ARIANE',
#  '#MONNA_VANNA',
#  '#MONNA_VANNA',
#  '#GISMONDA',
#  '#MAROUF',
#  '#MAROUF',
#  '#SAUTERIOT',
#  '#SAUTERIOT',
#  '#FIAMMETTE',
#  '#FIAMMETTE',
#  '#CHEMINEAU',
#  '#AIGLE',
#  '#AIGLE',
#  '#ST_ELIZABETH',
#  '#BARBER_OF_BAGDAD',
#  '#BARBER_OF_BAGDAD',
#  '#TAMING',
#  '#TAMING',
#  '#QUEEN_OF_SHEBA',
#  '#QUEEN_OF_SHEBA',
#  '#CRICKET',
#  '#KONIGSKINDER',
#  '#KONIGSKINDER',
#  '#HANSEL',
#  '#GOLDEN_CROSS',
#  '#GOLDEN_CROSS',
#  '#VERSIEGELT',
#  '#VERSIEGELT',
#  '#TROMPETER',
#  '#TROMPETER',
#  '#EVANGELIMANN',
#  '#EVANGELIMANN',
#  '#KUHREIGEN',
#  '#LOBETANZ',
#  '#LOBETANZ',
#  '#CORREGIDOR',
#  '#CORREGIDOR',
#  '#FEUERSNOT',
#  '#GUNTRAM',
#  '#SALOME',
#  '#ELEKTRA',
#  '#ROSENKAVALIER',
#  '#ARIADNE',
#  '#BARTERED',
#  '#BARTERED',
#  '#RUSSLAN',
#  '#RUSSLAN',
#  '#PRINCE_IGOR',
#  '#PRINCE_IGOR',
#  '#BORIS',
#  '#BORIS',
#  '#ONEGIN',
#  '#ONEGIN',
#  '#PIQUE_DAME',
#  '#COQ',
#  '#COQ',
#  '#MANRU',
#  '#MANRU',
#  '#SACRIFICE',
#  '#SACRIFICE',
#  '#PIPE',
#  '#SHANEWIS',
#  '#SHANEWIS',
#  '#TEMPLE_DANCER',
#  '#TEMPLE_DANCER',
#  '#LEGEND',
#  '#LEGEND',
#  '#NATOMAH',
#  '#NATOMAH',
#  '#MONA',
#  '#MONA',
#  '#CYRANO',
#  '#CYRANO',
#  '#CANTERBURY',
#  '#CANTERBURY',
#  '#GOYESCAS',
#  '#GARDEN_SAPHO',
#  '#HOMER_ORPHEUS',
#  '#HEMPEL_FIGARO',
#  '#SCOTTI_DG',
#  '#SEMBRICH_ZERLINA',
#  '#SCOTTI_DG2',
#  '#ALTEN_FLUTE',
#  '#MATZENAUER_FIDELIO',
#  '#FARRAR_TANNHAUSER',
#  '#TANNHAUSER_FINALE',
#  '#SEMBACH_LOHENGRIN',
#  '#HEINK_ORTRUD',
#  '#EAMES_ELSA',
#  '#HOMER_FRICKA',
#  '#LEHMANN_BRUNNHILDE',
#  '#VALKYR_I',
#  '#FREMSTAD_BRUNNHILDE',
#  '#FREMSTAD_SIEGLINDE',
#  '#WEIL_WOTAN',
#  '#WALKURE_III',
#  '#RESZKE_HAGEN',
#  '#RESZKE_SIEGFRIED',
#  '#NORDICA_ISOLDE',
#  '#LEHMANN_ISOLDE',
#  '#RESZKE_TRISTAN',
#  '#GADSKI_ISOLDE',
#  '#TERNINA_ISOLDE',
#  '#FISCHER_SACHS',
#  '#WEIL_GORITZ',
#  '#GRAILBEARER',
#  '#WINCKELMANN_MATERNA',
#  '#SCARIA_GURNEMANZ',
#  '#SAMMARCO_FIGARO',
#  '#GALLI-CURCI_ROSINA',
#  '#SEMBRICH_ROSINA',
#  '#ELIXIR_HEMPEL_CARUSO',
#  '#CARUSO_EDGARDO',
#  '#GALLI_CURCI_LUCIA',
#  '#GALLI-CURCI_GILDA',
#  '#CARUSO_DUKE',
#  '#RIGOLETTO_QUARTET',
#  '#MARTIN_MANRICO',
#  '#SCHUMANN-HEINK_AZUCENA',
#  '#GALLI-CURCI_VIOLETTA',
#  '#FARRAR_VIOLETTA',
#  '#SCOTTI_GERMONT',
#  '#EAMES_AIDA',
#  '#SALEZA_RADAMES',
#  '#HOMER_AMNERIS',
#  '#GALLI_AIDA',
#  '#ALDA_DESDEMONA',
#  '#AMATO_BARNABA',
#  '#CARUSO_ENZO',
#  '#HOMER_LAURA',
#  '#PLANCON_STBRIS',
#  '#JDERESZKE_RAOUL',
#  '#MARTHA_CAST',
#  '#PLANCON_MEPHISTOPHELES',
#  '#GALLI-CURCI_JULIETTE',
#  '#CARMEN_CAST',
#  '#CARUSO_JOSE1',
#  '#CARUSO_JOSE2',
#  '#CALVE_CARMEN',
#  '#AMATO_ESCAMILLO',
#  '#GADSKI_SANTUZZA',
#  '#BORI_IRIS',
#  '#CARUSO_CANIO',
#  '#FARRAR_NEDDA',
#  '#FARRAR_MIMI',
#  '#BOHEME_MOMUS',
#  '#CAVALIERI_TOSCA',
#  '#SCOTTI_SCARPIA',
#  '#EAMES_TOSCA',
#  '#CARUSO_MARIO',
#  '#FARRAR_TOSCA',
#  '#BUTTERFLY_I',
#  '#FARRAR_BUTTERFLY',
#  '#FANCIULLA_CAST',
#  '#FRANCESCA_CAST',
#  '#TRE_RE_CAST',
#  '#FARRAR_CATHERINE',
#  '#GALLI-CURCI_LAKME',
#  '#CARUSO_SAMSON',
#  '#GARDEN_GRISELIDIS',
#  '#GARDEN_THAIS',
#  '#THAIS_CAST',
#  '#FARRAR_THAIS',
#  '#THAIS_CAST_2',
#  '#CARUSO_GRIEUX',
#  '#GARDEN_JONGLEUR',
#  '#GARDEN_LOUISE',
#  '#BREVAL_SALAMMBO',
#  '#GARDEN_MELISANDE',
#  '#FARRAR_GOOSE',
#  '#HANSEL_GRETEL',
#  '#GARDEN_SALOME',
#  '#ROSENKAVALIER_CAST',
#  '#IGOR_BALLET',
#  '#BORIS_CAST',
#  '#FIGARO_CONCLUSION',
#  '#FIDELIO_CONCLUSION',
#  '#BARBER_CONCLUSION',
#  '#TRAVIATA']

# %%
url = "http://www.gutenberg.org/files/40540/40540-h/40540-h.htm" + links_with_text[0]
r  = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

# %%
# soup.find_all('a')
https://www.naxos.com/education/opera_synopses.asp?char=C#
http://www.metopera.org/Discover/Synopses/
http://www.musicwithease.com/opera-01.html
http://faculty.mdc.edu/sgrant/200operas.pdf
https://babel.hathitrust.org/cgi/ssd?id=hvd.ml1vwf
https://catalog.hathitrust.org/Search/Home?lookfor=Two%20hundred%20opera%20plots&searchtype=all&ft=&setft=false
# Out:
#   File "<ipython-input-35-829febac88fe>", line 2
#     https://www.naxos.com/education/opera_synopses.asp?char=C#
#            ^
# SyntaxError: invalid syntax
