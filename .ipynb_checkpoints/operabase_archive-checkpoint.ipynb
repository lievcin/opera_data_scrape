# %%
https://web.archive.org/web/20120510091223/http://operabase.com/plan.cgi?lang=en&season=2011/12
https://web.archive.org/web/20130223084132/http://www.operabase.com/plan.cgi?lang=en&season=2012/13
https://web.archive.org/web/20140729224252/http://operabase.com:80/plan.cgi?lang=en&season=2013/14
https://web.archive.org/web/20150924162245/http://operabase.com:80/plan.cgi?lang=en&season=2014/15
https://web.archive.org/web/20150905064133/http://operabase.com/plan.cgi?lang=en&season=2015/16
http://operabase.com/plan.cgi?lang=en&season=2017/18

# %%
from bs4 import BeautifulSoup
import requests, csv, string, re, datetime
from csv import writer

# %%
url = 'http://operabase.com/plan.cgi?lang=en&season=2017/18'
r  = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

# %%
countries  =[]
for l in soup.select('table a'):
    if 'plan.cgi?lang=en&season=2017/18&ci=' in l.get('href'):
        country = []
        country.append(l.text)
        country.append(l.get('href'))        
        countries.append(country)
i = 0
for c in countries:    
    url = 'http://operabase.com/' + c[1]
    country = c[0]
    r  = requests.get(url)
    soup = BeautifulSoup(r.text, "html5lib")
    schedules = soup.find_all('a')
    schedules = [s for s in schedules if 'view.cgi?lang=en&cal=' in s.get('href')]
    for schedule in schedules:
        city = schedule.previous_sibling.previous_sibling.find('b').text
        theatre = ','.join(schedule.previous_sibling.previous_sibling.text.split(',')[1:]).strip()        
        url_cal = 'http://operabase.com/' + schedule.get('href')
        print(url_cal)
        r_cal  = requests.get(url_cal)
        soup_cal = BeautifulSoup(r_cal.text, "html5lib")
        shows = soup_cal.find_all('b')[8:]
        for show in shows:
            info = []
            info.append(country)
            info.append(city)
            info.append(theatre)                            
            info.append(show.text)
            link = show.parent.parent.parent.find('a').get('href')
            date = link.split("date=")[-1]
            info.append(date)
            i += 1
            print(info)
# Out:
# http://operabase.com/view.cgi?lang=en&cal=wqti_1718
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Pêcheurs de perles', '20170922']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Pêcheurs de perles', '20170924']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Pêcheurs de perles', '20170925']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Ein deutsches Requiem', '20170930']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Zarzuela anthology', '20171021']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Carmen', '20180130']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Carmen', '20180131']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Carmen', '20180201']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Carmen', '20180202']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Carmen', '20180203']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Fledermaus', '20180329']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Fledermaus', '20180330']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Fledermaus', '20180331']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Fledermaus', '20180401']
# ['Albania', 'Tirana', 'Teatri Kombetar i Operas dhe Baletit / National Theatre of Opera and Ballet', 'Fledermaus', '20180402']
# http://operabase.com/view.cgi?lang=en&cal=eaye_1718
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Anoush', '20170905']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Requiem', '20170914']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Poliuto', '20171109']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Tosca', '20171126']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Arshak II', '20171130']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Poliuto', '20171212']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Il trovatore', '20171220']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Tosca', '20171222']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Poliuto', '20180104']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Poliuto', '20180204']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Tosca', '20180210']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Aida', '20180228']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Anoush', '20180301']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Sayat-Nova', '20180313']
# ['Armenia', 'Yerevan', 'Spendiarian Opera and Ballet Theatre', 'Anoush', '20180321']
# http://operabase.com/view.cgi?lang=en&cal=wabrl_1718
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180202']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180204']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180206']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180213']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180215']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180217']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180219']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180221']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180223']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180225']
# ['Austria', 'Bregenz', 'Vorarlberger Landestheater', 'Don Pasquale', '20180227']
# http://operabase.com/view.cgi?lang=en&cal=wagrb_1718
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20170930']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171001']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171004']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171005']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171015']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171018']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171025']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171029']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171102']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171103']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171104']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171109']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171118']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171119']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171124']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20171125']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171126']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171129']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20171201']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171203']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171206']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171210']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20171210']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171212']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171212']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171213']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171214']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20171215']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171215']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20171216']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171216']
# ['Austria', 'Graz', 'Oper Graz', 'Amahl und die nächtlichen Besucher', '20171216']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20171217']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20171221']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171223']
# ['Austria', 'Graz', 'Oper Graz', 'Bohème', '20171226']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20171231']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20180106']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20180110']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180117']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20180118']
# ['Austria', 'Graz', 'Oper Graz', 'Die menschliche Stimme', '20180120']
# ['Austria', 'Graz', 'Oper Graz', 'Die menschliche Stimme', '20180121']
# ['Austria', 'Graz', 'Oper Graz', 'Die menschliche Stimme', '20180123']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20180124']
# ['Austria', 'Graz', 'Oper Graz', 'Die menschliche Stimme', '20180125']
# ['Austria', 'Graz', 'Oper Graz', 'Die menschliche Stimme', '20180126']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180131']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180203']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180209']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20180215']
# ['Austria', 'Graz', 'Oper Graz', 'Nacht in Venedig', '20180302']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180303']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180304']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20180307']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180308']
# ['Austria', 'Graz', 'Oper Graz', 'Candide', '20180310']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180311']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180314']
# ['Austria', 'Graz', 'Oper Graz', 'Candide', '20180316']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180317']
# ['Austria', 'Graz', 'Oper Graz', 'Nozze', '20180318']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180321']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180323']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180406']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180407']
# ['Austria', 'Graz', 'Oper Graz', 'Candide', '20180408']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180412']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180413']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180414']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180415']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180418']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180420']
# ['Austria', 'Graz', 'Oper Graz', 'Ariane et Barbe-bleue', '20180422']
# ['Austria', 'Graz', 'Oper Graz', 'Eugen Onegin', '20180425']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180502']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180506']
# ['Austria', 'Graz', 'Oper Graz', 'Apollo e Dafne', '20180515']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180516']
# ['Austria', 'Graz', 'Oper Graz', 'Apollo e Dafne', '20180517']
# ['Austria', 'Graz', 'Oper Graz', 'Apollo e Dafne', '20180518']
# ['Austria', 'Graz', 'Oper Graz', 'Apollo e Dafne', '20180519']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20180524']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180525']
# ['Austria', 'Graz', 'Oper Graz', 'Mirada antigua', '20180527']
# ['Austria', 'Graz', 'Oper Graz', 'Antigone. Und kein Ende', '20180527']
# ['Austria', 'Graz', 'Oper Graz', 'Mirada antigua', '20180529']
# ['Austria', 'Graz', 'Oper Graz', 'Antigone. Und kein Ende', '20180529']
# ['Austria', 'Graz', 'Oper Graz', 'Il trovatore', '20180603']
# ['Austria', 'Graz', 'Oper Graz', 'Mirada antigua', '20180605']
# ['Austria', 'Graz', 'Oper Graz', 'Antigone. Und kein Ende', '20180605']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180606']
# ['Austria', 'Graz', 'Oper Graz', 'Mirada antigua', '20180608']
# ['Austria', 'Graz', 'Oper Graz', 'Antigone. Und kein Ende', '20180608']
# ['Austria', 'Graz', 'Oper Graz', 'Il viaggio a Reims', '20180610']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180614']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180615']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180616']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180621']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180622']
# ['Austria', 'Graz', 'Oper Graz', 'María de Buenos Aires', '20180623']
# http://operabase.com/view.cgi?lang=en&cal=wainl_1718
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20170923']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20170929']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20170930']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171001']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20171005']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171006']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20171014']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171019']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20171020']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171021']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171027']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171104']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20171104']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171105']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Orphée et Eurydice', '20171108']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171110']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171111']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171119']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171123']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171125']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171130']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171201']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171201']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171203']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171207']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171213']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171214']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171215']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20171216']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171217']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171217']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171220']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171221']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20171222']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Hoffmann', '20171226']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171228']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20171228']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20171229']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20171230']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171230']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20171231']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20171231']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20180103']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180105']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180107']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20180110']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180111']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180112']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20180113']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180121']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180125']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180127']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180128']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180131']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180203']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180207']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180208']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180209']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180210']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180215']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Vetter aus Dingsda', '20180216']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Gioconda', '20180216']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180217']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180218']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180225']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180301']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180302']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180304']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180308']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180309']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180311']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'West Side Story', '20180321']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180324']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180404']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180405']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180406']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180407']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180408']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180419']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180420']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180422']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180425']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180426']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180429']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180511']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180519']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180527']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180530']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180601']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180602']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180603']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180606']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Der Konsul', '20180607']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180609']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180610']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180617']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180622']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180623']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180627']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180630']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180701']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180704']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Martha', '20180705']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180706']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Rienzi', '20180707']
# ['Austria', 'Innsbruck', 'Tiroler Landestheater', 'Stein der Weisen', '20180708']
# http://operabase.com/view.cgi?lang=en&cal=wakl_1718
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170914']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170916']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170919']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170921']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170923']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170927']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20170929']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171006']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171011']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171014']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171017']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171102']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171104']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171107']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171110']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171111']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171112']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Traviata', '20171114']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171117']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171122']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171124']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171129']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171201']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171214']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171216']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171219']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Werther', '20171221']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171227']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171229']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20171231']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180103']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180105']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180114']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180116']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180201']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180203']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Don Giovanni', '20180210']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180301']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180306']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180308']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180310']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180314']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180316']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180318']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180322']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180323']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180324']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180327']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180407']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180408']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180411']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180413']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Lady Macbeth von Mtsensk', '20180414']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180418']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180419']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180421']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180425']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180428']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180504']
# ['Austria', 'Klagenfurt', 'Stadttheater Klagenfurt', 'Mutter Courage und ihre Kinder', '20180508']
# http://operabase.com/view.cgi?lang=en&cal=walit_1718
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170916']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170919']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170921']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170923']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170926']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170928']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20170930']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20170930']
# ['Austria', 'Linz', 'Landestheater Linz', 'La Rosinda', '20171002']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171004']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171008']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171011']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171016']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171022']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171025']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171026']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171028']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171029']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171101']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171102']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171104']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171107']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171109']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171110']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171111']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171112']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171113']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171115']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171117']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171121']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171122']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171122']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171123']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171125']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171128']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171130']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20171202']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171203']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171210']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171211']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20171213']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171215']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20171216']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171217']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171217']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20171219']
# ['Austria', 'Linz', 'Landestheater Linz', 'Hänsel und Gretel', '20171221']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20171223']
# ['Austria', 'Linz', 'Landestheater Linz', 'Hänsel und Gretel', '20171225']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20171226']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20171226']
# ['Austria', 'Linz', 'Landestheater Linz', 'Hänsel und Gretel', '20171230']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20171231']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180105']
# ['Austria', 'Linz', 'Landestheater Linz', 'Hänsel und Gretel', '20180106']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180107']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180108']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20180109']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180111']
# ['Austria', 'Linz', 'Landestheater Linz', 'Hänsel und Gretel', '20180112']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20180113']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180114']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180115']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180115']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180118']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180121']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180124']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180125']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180126']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180126']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180127']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180129']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180130']
# ['Austria', 'Linz', 'Landestheater Linz', 'Schaf', '20180202']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180203']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180204']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180206']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180208']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180210']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180216']
# ['Austria', 'Linz', 'Landestheater Linz', 'Frau ohne Schatten', '20180217']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180222']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180225']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180226']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180227']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180228']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180302']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180303']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180306']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180307']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180308']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180310']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180311']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180314']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180315']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180316']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180318']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180319']
# ['Austria', 'Linz', 'Landestheater Linz', 'Rigoletto', '20180320']
# ['Austria', 'Linz', 'Landestheater Linz', 'Unverhofftes Wiedersehen', '20180321']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180324']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180327']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180331']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180401']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180402']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180405']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180408']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180408']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180412']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180414']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180415']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180417']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180418']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180419']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180421']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180423']
# ['Austria', 'Linz', 'Landestheater Linz', 'Damnation de Faust', '20180424']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180424']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180428']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180429']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180503']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180505']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180507']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180511']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180515']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180518']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180519']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180522']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180524']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180525']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180527']
# ['Austria', 'Linz', 'Landestheater Linz', 'Brundibár', '20180528']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180529']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180601']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180602']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180607']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180609']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180610']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180611']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180613']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180614']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180615']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180618']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180619']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180620']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180622']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180623']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180626']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180628']
# ['Austria', 'Linz', 'Landestheater Linz', 'Eugen Onegin', '20180628']
# ['Austria', 'Linz', 'Landestheater Linz', 'Nacht in Venedig', '20180629']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180630']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180702']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180703']
# ['Austria', 'Linz', 'Landestheater Linz', 'Death in Venice', '20180706']
# ['Austria', 'Linz', 'Landestheater Linz', 'Così fan tutte', '20180706']
# http://operabase.com/view.cgi?lang=en&cal=wasal_1718
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20170923']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171001']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171003']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171007']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171014']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20171017']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171018']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20171020']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171025']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171026']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171029']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171031']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171102']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171103']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171105']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171107']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171111']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171114']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171115']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171118']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171119']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Oedipus rex', '20171121']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171124']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171215']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171219']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171222']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171228']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20171230']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Hoffmanns Erzählungen', '20180113']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180120']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180123']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180126']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180128']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180203']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180207']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180220']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180309']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180320']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20180321']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20180323']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180325']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20180331']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Sound of Music', '20180407']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180421']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180429']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180430']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180503']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180505']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180511']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180513']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Cardillac', '20180515']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180525']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180526']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Nozze', '20180530']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180531']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180602']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180606']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180608']
# ['Austria', 'Salzburg', 'Salzburger Landestheater', 'Flüchtling', '20180610']
# http://operabase.com/view.cgi?lang=en&cal=wawin_1718
# ['Austria', 'Wien', 'Neue Oper Wien', 'Antilope', '20171111']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Antilope', '20171114']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Antilope', '20171115']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Antilope', '20171116']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Ficus spricht', '20180614']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Radames', '20180614']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Radames', '20180616']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Ficus spricht', '20180616']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Radames', '20180618']
# ['Austria', 'Wien', 'Neue Oper Wien', 'Ficus spricht', '20180618']
# http://operabase.com/view.cgi?lang=en&cal=wawis_1718
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Il trovatore', '20170904']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Nozze', '20170905']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Barbiere', '20170906']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Il trovatore', '20170907']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Chowanschtschina', '20170908']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Nozze', '20170909']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Il trovatore', '20170910']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Chowanschtschina', '20170911']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Nozze', '20170912']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Il trovatore', '20170913']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Chowanschtschina', '20170914']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Nozze', '20170915']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20170916']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Chowanschtschina', '20170917']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20170918']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20170921']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Traviata', '20170924']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Traviata', '20170927']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Traviata', '20170929']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Bohème', '20170930']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Traviata', '20171002']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Bohème', '20171003']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171004']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Giovanni', '20171005']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Bohème', '20171006']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171007']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Giovanni', '20171008']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171010']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Giovanni', '20171011']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Pelléas et Mélisande', '20171012']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Giovanni', '20171013']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171014']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Pelléas et Mélisande', '20171015']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171017']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Pelléas et Mélisande', '20171018']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rusalka', '20171019']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Spieler', '20171020']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Pelléas et Mélisande', '20171021']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rusalka', '20171022']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Tosca', '20171023']
# ['Austria', 'Wien', 'Wiener Staatsoper', "Elisir d'amore", '20171024']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rusalka', '20171025']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Italiana in Algeri', '20171026']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Tosca', '20171027']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rusalka', '20171028']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Italiana in Algeri', '20171029']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Tosca', '20171030']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Katja Kabanova', '20171101']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Italiana in Algeri', '20171102']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Katja Kabanova', '20171104']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ballo in maschera', '20171105']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Katja Kabanova', '20171107']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ballo in maschera', '20171108']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Adriana Lecouvreur', '20171109']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ballo in maschera', '20171111']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Adriana Lecouvreur', '20171112']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Adriana Lecouvreur', '20171115']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20171116']
# ['Austria', 'Wien', 'Wiener Staatsoper', "Elisir d'amore", '20171117']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Adriana Lecouvreur', '20171118']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20171119']
# ['Austria', 'Wien', 'Wiener Staatsoper', "Elisir d'amore", '20171120']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Butterfly', '20171121']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20171122']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ariadne', '20171123']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Butterfly', '20171124']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Salome', '20171125']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ariadne', '20171126']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Pasquale', '20171127']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Ariadne', '20171129']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Pasquale', '20171130']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Daphne', '20171201']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Don Pasquale', '20171202']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Lulu', '20171203']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Daphne', '20171204']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Elektra', '20171205']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Lulu', '20171206']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Daphne', '20171207']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Elektra', '20171208']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Lulu', '20171209']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rosenkavalier', '20171210']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Elektra', '20171211']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Lulu', '20171212']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rosenkavalier', '20171213']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Arabella', '20171214']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Lulu', '20171215']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rosenkavalier', '20171216']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Arabella', '20171218']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Rosenkavalier', '20171219']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Arabella', '20171221']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Zauberflöte', '20171222']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Zauberflöte', '20171225']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Hänsel und Gretel', '20171226']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Zauberflöte', '20171227']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Zauberflöte', '20171229']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Hänsel und Gretel', '20171230']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Fledermaus', '20171231']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Fledermaus', '20180101']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Hänsel und Gretel', '20180102']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Fledermaus', '20180103']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'I puritani', '20180104']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Fledermaus', '20180105']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'I puritani', '20180107']
# ['Austria', 'Wien', 'Wiener Staatsoper', 'Tosca', '20180108']
# ...
# http://operabase.com/view.cgi?lang=en&cal=nase_1718
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170805']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170806']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170809']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170812']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170813']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170816']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170818']
# ['United States', 'Seattle', 'Seattle Opera', 'Butterfly', '20170819']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170907']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170908']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170910']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170914']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170915']
# ['United States', 'Seattle', 'Seattle Opera', 'An American Dream', '20170917']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171014']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171015']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171018']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171020']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171021']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171022']
# ['United States', 'Seattle', 'Seattle Opera', 'Barber', '20171028']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180113']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180114']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180117']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180120']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180124']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180126']
# ['United States', 'Seattle', 'Seattle Opera', 'Così fan tutte', '20180127']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180224']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180225']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180228']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180303']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180307']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180309']
# ['United States', 'Seattle', 'Seattle Opera', 'Beatrice and Benedict', '20180310']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180505']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180506']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180509']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180511']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180512']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180513']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180516']
# ['United States', 'Seattle', 'Seattle Opera', 'Aida', '20180519']
# http://operabase.com/view.cgi?lang=en&cal=nash_1718
# ['United States', 'Shreveport', 'Shreveport Opera', 'Magic Flute', '20171019']
# ['United States', 'Shreveport', 'Shreveport Opera', 'Beauty and the Beast', '20180420']
# ['United States', 'Shreveport', 'Shreveport Opera', 'Beauty and the Beast', '20180421']
# http://operabase.com/view.cgi?lang=en&cal=nasy_1718
# ['United States', 'Syracuse', 'Syracuse Opera', 'Carmen', '20171020']
# ['United States', 'Syracuse', 'Syracuse Opera', 'Carmen', '20171022']
# ['United States', 'Syracuse', 'Syracuse Opera', 'Traviata', '20180102']
# ['United States', 'Syracuse', 'Syracuse Opera', 'Traviata', '20180104']
# ['United States', 'Syracuse', 'Syracuse Opera', 'Butterfly', '20180413']
# ['United States', 'Syracuse', 'Syracuse Opera', 'Butterfly', '20180415']
# http://operabase.com/view.cgi?lang=en&cal=natc_1718
# ['United States', 'Tacoma', 'Tacoma Opera', 'Marriage of Figaro', '20171028']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Marriage of Figaro', '20171103']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Marriage of Figaro', '20171105']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Carmen', '20180203']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Carmen', '20180209']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Carmen', '20180211']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Merry Widow', '20180414']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Merry Widow', '20180420']
# ['United States', 'Tacoma', 'Tacoma Opera', 'Merry Widow', '20180422']
# http://operabase.com/view.cgi?lang=en&cal=nata_1718
# ['United States', 'Tampa', 'Opera Tampa', 'Barber', '20180202']
# ['United States', 'Tampa', 'Opera Tampa', 'Barber', '20180204']
# ['United States', 'Tampa', 'Opera Tampa', 'Marriage of Figaro', '20180302']
# ['United States', 'Tampa', 'Opera Tampa', 'Marriage of Figaro', '20180304']
# ['United States', 'Tampa', 'Opera Tampa', 'Macbeth', '20180413']
# ['United States', 'Tampa', 'Opera Tampa', 'Macbeth', '20180415']
# http://operabase.com/view.cgi?lang=en&cal=nato_1718
# ['United States', 'Toledo', 'Toledo Opera', 'Pearl Fishers', '20171013']
# ['United States', 'Toledo', 'Toledo Opera', 'Pearl Fishers', '20171015']
# ['United States', 'Toledo', 'Toledo Opera', 'Rigoletto', '20180126']
# ['United States', 'Toledo', 'Toledo Opera', 'Rigoletto', '20180128']
# http://operabase.com/view.cgi?lang=en&cal=natr_1718
# ['United States', 'Trenton', 'Bohème Opera', 'Pagliacci', '20180420']
# ['United States', 'Trenton', 'Bohème Opera', 'Cavalleria rusticana', '20180420']
# ['United States', 'Trenton', 'Bohème Opera', 'Pagliacci', '20180422']
# ['United States', 'Trenton', 'Bohème Opera', 'Cavalleria rusticana', '20180422']
# http://operabase.com/view.cgi?lang=en&cal=natu_1718
# ['United States', 'Tulsa', 'Tulsa Opera', 'Faust', '20171020']
# ['United States', 'Tulsa', 'Tulsa Opera', 'Faust', '20171022']
# ['United States', 'Tulsa', 'Tulsa Opera', 'Turandot', '20180427']
# ['United States', 'Tulsa', 'Tulsa Opera', 'Turandot', '20180429']
# http://operabase.com/view.cgi?lang=en&cal=nawac_1718
# ['United States', 'Washington', 'Opera Camerata of Washington', 'Marriage of Figaro', '20171006']
# ['United States', 'Washington', 'Opera Camerata of Washington', 'Pirates', '20180309']
# http://operabase.com/view.cgi?lang=en&cal=nawax_1718
# ['United States', 'Washington', 'Washington Concert Opera', 'Straniera', '20171119']
# ['United States', 'Washington', 'Washington Concert Opera', 'Maria di Rohan', '20180218']
# http://operabase.com/view.cgi?lang=en&cal=nawal_1718
# ['United States', 'Washington', 'Opera Lafayette', 'Erminia, Tancredi, Polidoro e Pastore', '20180130']
# ['United States', 'Washington', 'Opera Lafayette', 'Erminia, Tancredi, Polidoro e Pastore', '20180131']
# http://operabase.com/view.cgi?lang=en&cal=nawao_1718
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170909']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170910']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170913']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170915']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170916']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170917']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170918']
# ['United States', 'Washington', 'Washington National Opera', 'Aida', '20170923']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171104']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171106']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171108']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171111']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171114']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171117']
# ['United States', 'Washington', 'Washington National Opera', 'Alcina', '20171119']
# ['United States', 'Washington', 'Washington National Opera', 'Little Prince', '20171214']
# ['United States', 'Washington', 'Washington National Opera', 'Little Prince', '20171217']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180303']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180305']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180308']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180311']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180314']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180316']
# ['United States', 'Washington', 'Washington National Opera', 'Don Carlo', '20180317']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180428']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180502']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180504']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180505']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180507']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180509']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180511']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180512']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180513']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180514']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180517']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180518']
# ['United States', 'Washington', 'Washington National Opera', 'Barber', '20180519']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180520']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180522']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180524']
# ['United States', 'Washington', 'Washington National Opera', 'Candide', '20180526']
# http://operabase.com/view.cgi?lang=en&cal=napb_1718
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Concert', '20171209']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Tosca', '20180126']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Tosca', '20180127']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Tosca', '20180128']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Candide', '20180223']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Candide', '20180224']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Candide', '20180225']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Nozze', '20180323']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Nozze', '20180324']
# ['United States', 'West Palm Beach', 'Palm Beach Opera', 'Nozze', '20180325']
# http://operabase.com/view.cgi?lang=en&cal=nawi_1718
# ['United States', 'Wilmington', 'OperaDelaware', 'Suor Angelica', '20180428']
# ['United States', 'Wilmington', 'OperaDelaware', 'Il tabarro', '20180428']
# ['United States', 'Wilmington', 'OperaDelaware', "Buoso's Ghost", '20180429']
# ['United States', 'Wilmington', 'OperaDelaware', 'Gianni Schicchi', '20180429']
# ['United States', 'Wilmington', 'OperaDelaware', "Buoso's Ghost", '20180505']
# ['United States', 'Wilmington', 'OperaDelaware', 'Gianni Schicchi', '20180505']
# ['United States', 'Wilmington', 'OperaDelaware', 'Suor Angelica', '20180506']
# ['United States', 'Wilmington', 'OperaDelaware', 'Il tabarro', '20180506']
# http://operabase.com/view.cgi?lang=en&cal=naws_1718
# ['United States', 'Winston Salem', 'Piedmont Opera', 'Silent Night', '20171027']
# ['United States', 'Winston Salem', 'Piedmont Opera', 'Silent Night', '20171029']
# ['United States', 'Winston Salem', 'Piedmont Opera', 'Pirates', '20180323']
# ['United States', 'Winston Salem', 'Piedmont Opera', 'Pirates', '20180325']
# ['United States', 'Winston Salem', 'Piedmont Opera', 'Pirates', '20180327']
# http://operabase.com/view.cgi?lang=en&cal=etta_1718
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Barbiere', '20170914']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Sadokat', '20170921']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Il trovatore', '20170923']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Pêcheurs de perles', '20170924']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Bohème', '20170928']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Aida', '20170930']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Traviata', '20171005']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tsarskaya nevesta', '20171007']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Carmen', '20171019']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Aida', '20171021']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Pêcheurs de perles', '20171022']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Traviata', '20171102']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Il trovatore', '20171104']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', "Elisir d'amore", '20171109']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Pêcheurs de perles', '20171111']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Lucia', '20171112']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Aida', '20171118']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Carmen', '20171125']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20171126']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20171130']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tsarskaya nevesta', '20171202']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Il trovatore', '20171207']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20171209']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Sadokat', '20171210']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20180120']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', "Elisir d'amore", '20180126']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Aida', '20180127']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tsarskaya nevesta', '20180203']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Carmen', '20180210']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Lucia', '20180211']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Bohème', '20180215']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Aida', '20180217']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20180224']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Pêcheurs de perles', '20180225']
# ['Uzbekistan', 'Tashkent', 'Bolshoi Opera and Ballet Theatre Alisher Navoï', 'Tosca', '20180310']

# %%
i
# Out:
# 19886
